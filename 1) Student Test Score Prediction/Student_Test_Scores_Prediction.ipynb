# %% [markdown]
# <a href="https://colab.research.google.com/github/nujl/Liberty-Data-Science/blob/main/1)%20Student%20Test%20Score%20Prediction/Student_Test_Scores_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %load_ext rpy2.ipython

# %% [markdown]
# Python Packages

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# R Packages

# %%
# %%R
# if(!require('pacman')) {
#   install.packages('pacman')
# }
# pacman::p_load(ggplot2, dplyr, car, gridExtra)

# %% [markdown]
# ---
# # Data

# %%
# %%R
# df <- read.csv("https://raw.githubusercontent.com/nujl/Liberty-Data-Science/main/1)%20Student%20Test%20Score%20Prediction/test_scores.csv")
# summary(df)
# Out:
#     school          school_setting     school_type         classroom
#  Length:2133        Length:2133        Length:2133        Length:2133
#  Class :character   Class :character   Class :character   Class :character
#  Mode  :character   Mode  :character   Mode  :character   Mode  :character
#
#
#
#  teaching_method      n_student     student_id           gender
#  Length:2133        Min.   :14.0   Length:2133        Length:2133
#  Class :character   1st Qu.:20.0   Class :character   Class :character
#  Mode  :character   Median :22.0   Mode  :character   Mode  :character
#                     Mean   :22.8
#                     3rd Qu.:27.0
#                     Max.   :31.0
#     lunch              pretest         posttest
#  Length:2133        Min.   :22.00   Min.   : 32.0
#  Class :character   1st Qu.:44.00   1st Qu.: 56.0
#  Mode  :character   Median :56.00   Median : 68.0
#                     Mean   :54.96   Mean   : 67.1
#                     3rd Qu.:65.00   3rd Qu.: 77.0
#                     Max.   :93.00   Max.   :100.0

# %%
df = %R df
df.head()
# Out:
#   school school_setting school_type classroom teaching_method  n_student  \
# 1  ANKYI          Urban  Non-public       6OL        Standard       20.0
# 2  ANKYI          Urban  Non-public       6OL        Standard       20.0
# 3  ANKYI          Urban  Non-public       6OL        Standard       20.0
# 4  ANKYI          Urban  Non-public       6OL        Standard       20.0
# 5  ANKYI          Urban  Non-public       6OL        Standard       20.0
#
#   student_id  gender             lunch  pretest  posttest
# 1      2FHT3  Female  Does not qualify     62.0      72.0
# 2      3JIVH  Female  Does not qualify     66.0      79.0
# 3      3XOWE    Male  Does not qualify     64.0      76.0
# 4      556O0  Female  Does not qualify     61.0      77.0
# 5      74LOE    Male  Does not qualify     64.0      76.0

# %%
na_dict = {col:sum(df[col].isna()) for col in df.columns}
pd.Series(na_dict)
# Out:
# school             0
# school_setting     0
# school_type        0
# classroom          0
# teaching_method    0
# n_student          0
# student_id         0
# gender             0
# lunch              0
# pretest            0
# posttest           0
# dtype: int64

# %% [markdown]
# No null values

# %% [markdown]
# ---
# # EDA
# - Categorical variables except classroom and student id

# %%
import seaborn as sns
import matplotlib.pyplot as plt

cat_cols = ["school", "school_setting", "school_type", "teaching_method", "gender", "lunch"]
cords = [(0,0), (0,1), (0,2), (1,0), (1,1), (1,2)]
fig, axs = plt.subplots(2,3, figsize=(20, 20))

for i,col in enumerate(cat_cols):
    vals = df[col].value_counts().to_dict()
    sns.barplot(x=list(vals.keys()), y=list(vals.values()), ax=axs[cords[i]])
    axs[cords[i]].set_title(col)

# %% [markdown]
# - Numerical Variables

# %%
# %%R
# library(gridExtra)
#
# p1 <- ggplot(df)+
#   geom_histogram(aes(x=pretest))
# p2 <- ggplot(df)+
#   geom_histogram(aes(x=posttest))
# p3 <- ggplot(df)+
#   geom_histogram(aes(x=n_student))
#
# grid.arrange(p1, p2, p3, nrow=3)
# Out:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.

# %%
# %%R
# as.factor(df$n_student)
# best_classes <- df %>%
#   group_by(school, classroom) %>%
#   summarise(
#     score = mean(posttest)
#   )
# best_classes <- data.frame(best_classes)
# head(best_classes[order(best_classes$score, decreasing=TRUE),])
# Out:
# `summarise()` has grouped output by 'school'. You can override using the
# `.groups` argument.
#    school classroom    score
# 42  IDGFP       P2A 98.41176
# 68  UKPGS       08N 93.85714
# 69  UKPGS       9AW 93.16000
# 40  IDGFP       98D 92.04762
# 70  UKPGS       IPU 91.52632
# 93  ZMNYA       V77 90.08696

# %%
# %%R
# df %>%
#   group_by(school, classroom) %>%
#   summarise(
#       count = n()
#   )
# Out:
# `summarise()` has grouped output by 'school'. You can override using the
# `.groups` argument.
# # A tibble: 97 × 3
# # Groups:   school [23]
#    school classroom count
#    <chr>  <chr>     <int>
#  1 ANKYI  6OL          20
#  2 ANKYI  ZNS          21
#  3 CCAAW  2B1          18
#  4 CCAAW  EPS          20
#  5 CCAAW  IQN          15
#  6 CCAAW  PGK          21
#  7 CCAAW  UHU          16
#  8 CCAAW  UWK          19
#  9 CIMBB  A33          19
# 10 CIMBB  EID          21
# # … with 87 more rows

# %%
# %%R
# df %>%
#   group_by(lunch) %>%
#   summarise(
#       avg_posttest = mean(posttest),
#       avg_pretest = mean(pretest)
#   )
# Out:
# # A tibble: 2 × 3
#   lunch                            avg_posttest avg_pretest
#   <chr>                                   <dbl>       <dbl>
# 1 Does not qualify                         74.4        62.3
# 2 Qualifies for reduced/free lunch         57.5        45.2

# %% [markdown]
# - Students from UKPGS performed extremely well
# - 23 schools, 97 classrooms in total
# - Can't use student_id because they're all unique
# - Distribution of posttest and pretest approximately normal, might have to scale for better performance, but I decided not to
# - Might not need school since theres classroom data
# - Somehow lunch might be a significant variable, probably because qualification for free lunch can indicate that ones not rich

# %% [markdown]
# ---
# # Multiple Regression using R

# %%
# %%R
# df.clean <- subset(df, select=-c(student_id))
#
# #approx 3/4 of whole dataset
# inds <- sample(nrow(df.clean), 1700)
# train <- df.clean[inds,]
# test <- df.clean[-inds,]
#
# fit1 <- lm(posttest ~ ., data=train)
# Anova(fit1)
# Out:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Note: model has aliased coefficients
#       sums of squares computed by model comparison
# Anova Table (Type II tests)
#
# Response: posttest
#                  Sum Sq   Df  F value    Pr(>F)
# school                     0
# school_setting             0
# school_type                0
# classroom        4081.2   72   7.1491 < 2.2e-16 ***
# teaching_method            0
# n_student                  0
# gender             40.5    1   5.1129   0.02388 *
# lunch             477.2    1  60.1838 1.528e-14 ***
# pretest          2621.7    1 330.6632 < 2.2e-16 ***
# Residuals       12685.9 1600
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# %%R
# df.clean2 <- subset(df.clean, select=-c(school, school_setting, school_type, n_student, teaching_method)) # removed all variables that have no F statistic
# fit2 <- lm(posttest ~ ., data=df.clean2)
# Anova(fit2)
# Out:
# Anova Table (Type II tests)
#
# Response: posttest
#            Sum Sq   Df F value    Pr(>F)
# classroom 24117.9   96  32.291 < 2.2e-16 ***
# gender       64.3    1   8.269  0.004075 **
# lunch       572.5    1  73.579 < 2.2e-16 ***
# pretest    3228.5    1 414.954 < 2.2e-16 ***
# Residuals 15817.3 2033
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# %%R
# df.clean3 <- subset(df.clean2, select=-c(gender)) # removed gender because pvalue > 0.001
# fit.final <- lm(posttest ~ ., data=df.clean3)
# Anova(fit.final)
# Out:
# Anova Table (Type II tests)
#
# Response: posttest
#            Sum Sq   Df F value    Pr(>F)
# classroom 24054.0   96  32.090 < 2.2e-16 ***
# lunch       568.3    1  72.785 < 2.2e-16 ***
# pretest    3317.8    1 424.915 < 2.2e-16 ***
# Residuals 15881.6 2034
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# %%R
# summary(fit.final) # Final model, each classroom and lunch status are intercepts and pretest is the slope
# Out:
# Call:
# lm(formula = posttest ~ ., data = df.clean3)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -9.6090 -1.8041  0.0429  1.8096  9.6912
#
# Coefficients:
#                                        Estimate Std. Error t value Pr(>|t|)
# (Intercept)                            52.54662    1.60932  32.651  < 2e-16 ***
# classroom08N                            5.92833    0.88078   6.731 2.19e-11 ***
# classroom0N7                          -10.19068    0.98745 -10.320  < 2e-16 ***
# classroom18K                          -14.43585    0.93482 -15.442  < 2e-16 ***
# classroom197                           -0.65947    0.97832  -0.674 0.500334
# classroom1Q1                           -9.01785    0.86297 -10.450  < 2e-16 ***
# classroom1SZ                           -9.12657    0.89153 -10.237  < 2e-16 ***
# classroom1UU                            0.88288    0.83781   1.054 0.292102
# classroom1VD                          -11.17003    1.00150 -11.153  < 2e-16 ***
# classroom21Q                          -17.33455    1.02120 -16.975  < 2e-16 ***
# classroom2AP                          -12.02686    0.90899 -13.231  < 2e-16 ***
# classroom2B1                            0.09355    0.91602   0.102 0.918662
# classroom2BR                          -13.37447    0.99068 -13.500  < 2e-16 ***
# classroom341                          -16.42815    1.07170 -15.329  < 2e-16 ***
# classroom3D0                          -22.75973    1.19085 -19.112  < 2e-16 ***
# classroom3XJ                          -14.61452    0.95075 -15.372  < 2e-16 ***
# classroom4NN                           -6.04434    0.85727  -7.051 2.43e-12 ***
# classroom5JK                          -20.76218    1.12918 -18.387  < 2e-16 ***
# classroom5LQ                            2.42139    0.89991   2.691 0.007189 **
# classroom5SZ                            0.09573    0.93054   0.103 0.918068
# classroom62L                           -5.25976    0.85030  -6.186 7.45e-10 ***
# classroom6C1                           -6.07425    0.95235  -6.378 2.21e-10 ***
# classroom6OL                           -5.21990    0.88479  -5.900 4.26e-09 ***
# classroom6U9                          -14.77047    0.98636 -14.975  < 2e-16 ***
# classroom7BL                          -17.64451    0.99874 -17.667  < 2e-16 ***
# classroom98D                            7.13605    0.85578   8.339  < 2e-16 ***
# classroom9AW                            5.26578    0.84590   6.225 5.83e-10 ***
# classroomA33                           -7.55372    0.91541  -8.252 2.77e-16 ***
# classroomA93                          -16.29832    1.12532 -14.483  < 2e-16 ***
# classroomAE1                            2.50123    0.90580   2.761 0.005808 **
# classroomAJ1                           -7.12463    0.88204  -8.077 1.12e-15 ***
# classroomBFY                          -13.07425    0.91382 -14.307  < 2e-16 ***
# classroomCD8                           -2.68514    0.93515  -2.871 0.004130 **
# classroomCII                          -12.75280    0.93313 -13.667  < 2e-16 ***
# classroomCXC                          -21.32750    1.13258 -18.831  < 2e-16 ***
# classroomD33                           -4.06901    0.87222  -4.665 3.29e-06 ***
# classroomDFQ                           -1.58321    0.90787  -1.744 0.081333 .
# classroomEID                           -2.99449    0.85959  -3.484 0.000505 ***
# classroomENO                           -4.05592    0.91841  -4.416 1.06e-05 ***
# classroomEPS                            3.19904    0.87197   3.669 0.000250 ***
# classroomFS3                           -6.81291    0.91262  -7.465 1.23e-13 ***
# classroomG2L                           -0.26925    0.90247  -0.298 0.765470
# classroomGYM                          -13.77562    0.98597 -13.972  < 2e-16 ***
# classroomH7S                            3.73408    0.91847   4.066 4.97e-05 ***
# classroomHCB                          -12.38032    0.99900 -12.393  < 2e-16 ***
# classroomHKF                          -22.57237    1.14665 -19.686  < 2e-16 ***
# classroomHUJ                            2.23684    0.91409   2.447 0.014487 *
# classroomIEM                          -12.09884    1.04109 -11.621  < 2e-16 ***
# classroomIPU                            6.92070    0.87721   7.889 4.91e-15 ***
# classroomIQN                           -0.22883    0.95587  -0.239 0.810820
# classroomJ6X                          -13.35007    1.03117 -12.947  < 2e-16 ***
# classroomJ8J                           -8.03302    0.91327  -8.796  < 2e-16 ***
# classroomJGD                           -2.63092    0.98869  -2.661 0.007852 **
# classroomKR1                           -3.56434    1.01201  -3.522 0.000438 ***
# classroomKXB                            5.83412    0.88882   6.564 6.63e-11 ***
# classroomNOR                            0.75386    0.83513   0.903 0.366797
# classroomNWZ                           -9.10518    0.90322 -10.081  < 2e-16 ***
# classroomO6A                          -14.25033    1.01431 -14.049  < 2e-16 ***
# classroomOMI                          -10.55726    0.87464 -12.070  < 2e-16 ***
# classroomP2A                           10.05935    0.93423  10.768  < 2e-16 ***
# classroomP8I                           -4.19372    0.86768  -4.833 1.44e-06 ***
# classroomPBA                          -17.52013    1.04106 -16.829  < 2e-16 ***
# classroomPC6                           -3.41833    0.90991  -3.757 0.000177 ***
# classroomPGH                            6.65015    0.83341   7.979 2.43e-15 ***
# classroomPGK                           -1.07292    0.85625  -1.253 0.210333
# classroomPW5                          -10.24644    1.04576  -9.798  < 2e-16 ***
# classroomQ0E                          -13.12181    1.05767 -12.406  < 2e-16 ***
# classroomQA2                          -17.59289    0.99668 -17.652  < 2e-16 ***
# classroomQTU                          -20.51382    1.14752 -17.877  < 2e-16 ***
# classroomRA5                            0.20185    0.91986   0.219 0.826332
# classroomRK7                          -13.74412    0.96312 -14.270  < 2e-16 ***
# classroomROP                           -2.33245    0.85006  -2.744 0.006125 **
# classroomS98                           -4.50886    0.85851  -5.252 1.66e-07 ***
# classroomSSP                           -3.73571    0.94430  -3.956 7.88e-05 ***
# classroomST7                           -7.32112    0.91240  -8.024 1.71e-15 ***
# classroomSUR                          -12.25484    0.89386 -13.710  < 2e-16 ***
# classroomTB5                          -17.03046    1.05033 -16.214  < 2e-16 ***
# classroomTSA                           -4.21852    0.91602  -4.605 4.37e-06 ***
# classroomU6J                          -18.04930    1.05572 -17.097  < 2e-16 ***
# classroomUHU                           -4.16464    0.97813  -4.258 2.16e-05 ***
# classroomUWK                           -3.28208    0.89205  -3.679 0.000240 ***
# classroomV77                            6.36355    0.83371   7.633 3.51e-14 ***
# classroomVA6                          -15.53186    1.05063 -14.783  < 2e-16 ***
# classroomW8A                          -10.63685    1.04947 -10.135  < 2e-16 ***
# classroomX2O                           -0.90120    0.84692  -1.064 0.287414
# classroomX6Z                           -4.73288    0.91472  -5.174 2.52e-07 ***
# classroomX78                           -8.67966    0.91673  -9.468  < 2e-16 ***
# classroomXJ8                           -9.24472    0.88878 -10.402  < 2e-16 ***
# classroomXXE                            2.52508    0.85198   2.964 0.003074 **
# classroomXXJ                           -7.52259    0.84453  -8.907  < 2e-16 ***
# classroomXZ4                           -8.31084    0.89491  -9.287  < 2e-16 ***
# classroomXZM                           -2.51265    0.90738  -2.769 0.005671 **
# classroomYTB                          -16.03607    1.11197 -14.421  < 2e-16 ***
# classroomYUC                          -14.45220    1.00285 -14.411  < 2e-16 ***
# classroomZBH                          -18.24214    1.00771 -18.103  < 2e-16 ***
# classroomZDT                           -9.29922    0.88876 -10.463  < 2e-16 ***
# classroomZNS                           -8.73818    0.89636  -9.749  < 2e-16 ***
# lunchQualifies for reduced/free lunch  -1.88250    0.22066  -8.531  < 2e-16 ***
# pretest                                 0.42241    0.02049  20.613  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 2.794 on 2034 degrees of freedom
# Multiple R-squared:  0.9619,	Adjusted R-squared:  0.9601
# F-statistic: 524.3 on 98 and 2034 DF,  p-value: < 2.2e-16

# %%
# %%R
# X_test <- subset(test, select=-c(school, school_setting, school_type, n_student, teaching_method, posttest))
# Y_test <- subset(test, select=posttest)
# preds <- predict(fit2, X_test)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

def eval(ytest, pred):
    ytest = np.array(ytest)
    ytest.tolist()
    ytest = [y[0] for y in ytest]
    pred = np.array(pred)
    print(f"MSE: {mean_squared_error(ytest, pred)}")
    print(f"R2Score: {r2_score(ytest, pred)}")

    return ytest, pred

ytest = %R Y_test
pred = %R preds
ytest, pred = eval(ytest, pred)
# Out:
# MSE: 6.875245225175045
# R2Score: 0.9663493495898943

# %%
plt.scatter(ytest, pred)

# %% [markdown]
# # Neural Nets

# %%
df_new = df.drop(columns=["student_id"])
df_new = pd.get_dummies(df_new)

from sklearn.model_selection import train_test_split

X = df_new.drop(columns=["posttest"], inplace=False)
y = df_new.posttest

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from tensorflow import keras
from tensorflow.keras import layers

# %%
model = keras.Sequential()

model.add(keras.Input(shape=(X.shape[1])))

model.add(layers.Dense(256,kernel_initializer='normal',activation='relu'))

model.add(layers.Dense(128,activation='relu'))

model.add(layers.Dense(64,activation='relu'))

model.add(layers.Dense(32,activation='relu'))

model.add(layers.Dense(1,activation='linear'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               34304
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dense_3 (Dense)             (None, 32)                2080
#
#  dense_4 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 77,569
# Trainable params: 77,569
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    loss="mse",
    optimizer="adam",
    metrics=["mse"]
)

# %%
history = model.fit(
    X_train, y_train, validation_data=(X_test, y_test), batch_size=128, epochs=150, verbose=1
)
# Out:
# Epoch 1/150
# 12/12 [==============================] - 1s 23ms/step - loss: 2732.3047 - mse: 2732.3047 - val_loss: 613.4346 - val_mse: 613.4346
# Epoch 2/150
# 12/12 [==============================] - 0s 8ms/step - loss: 256.8248 - mse: 256.8248 - val_loss: 231.6752 - val_mse: 231.6752
# Epoch 3/150
# 12/12 [==============================] - 0s 9ms/step - loss: 83.2131 - mse: 83.2131 - val_loss: 101.1929 - val_mse: 101.1929
# Epoch 4/150
# 12/12 [==============================] - 0s 8ms/step - loss: 51.1389 - mse: 51.1389 - val_loss: 33.5273 - val_mse: 33.5273
# Epoch 5/150
# 12/12 [==============================] - 0s 7ms/step - loss: 29.1659 - mse: 29.1659 - val_loss: 24.2435 - val_mse: 24.2435
# Epoch 6/150
# 12/12 [==============================] - 0s 8ms/step - loss: 21.6544 - mse: 21.6544 - val_loss: 20.3565 - val_mse: 20.3565
# Epoch 7/150
# 12/12 [==============================] - 0s 8ms/step - loss: 18.7774 - mse: 18.7774 - val_loss: 19.1399 - val_mse: 19.1399
# Epoch 8/150
# 12/12 [==============================] - 0s 7ms/step - loss: 17.7773 - mse: 17.7773 - val_loss: 18.2017 - val_mse: 18.2017
# Epoch 9/150
# 12/12 [==============================] - 0s 9ms/step - loss: 16.9142 - mse: 16.9142 - val_loss: 17.5939 - val_mse: 17.5939
# Epoch 10/150
# 12/12 [==============================] - 0s 7ms/step - loss: 16.3416 - mse: 16.3416 - val_loss: 17.0231 - val_mse: 17.0231
# Epoch 11/150
# 12/12 [==============================] - 0s 8ms/step - loss: 15.8228 - mse: 15.8228 - val_loss: 16.5890 - val_mse: 16.5890
# Epoch 12/150
# 12/12 [==============================] - 0s 9ms/step - loss: 15.4223 - mse: 15.4223 - val_loss: 16.3031 - val_mse: 16.3031
# Epoch 13/150
# 12/12 [==============================] - 0s 7ms/step - loss: 14.8534 - mse: 14.8534 - val_loss: 15.7467 - val_mse: 15.7467
# Epoch 14/150
# 12/12 [==============================] - 0s 8ms/step - loss: 14.4634 - mse: 14.4634 - val_loss: 15.3307 - val_mse: 15.3307
# Epoch 15/150
# 12/12 [==============================] - 0s 9ms/step - loss: 14.0461 - mse: 14.0461 - val_loss: 15.0988 - val_mse: 15.0988
# Epoch 16/150
# 12/12 [==============================] - 0s 8ms/step - loss: 13.8448 - mse: 13.8448 - val_loss: 14.8384 - val_mse: 14.8384
# Epoch 17/150
# 12/12 [==============================] - 0s 8ms/step - loss: 13.3924 - mse: 13.3924 - val_loss: 14.5064 - val_mse: 14.5064
# Epoch 18/150
# 12/12 [==============================] - 0s 8ms/step - loss: 13.0219 - mse: 13.0219 - val_loss: 14.0717 - val_mse: 14.0717
# Epoch 19/150
# 12/12 [==============================] - 0s 9ms/step - loss: 12.6880 - mse: 12.6880 - val_loss: 13.9090 - val_mse: 13.9090
# Epoch 20/150
# 12/12 [==============================] - 0s 7ms/step - loss: 12.3217 - mse: 12.3217 - val_loss: 13.4153 - val_mse: 13.4153
# Epoch 21/150
150
# 12/12 [==============================] - 0s 9ms/step - loss: 9.8592 - mse: 9.8592 - val_loss: 11.7236 - val_mse: 11.7236
# Epoch 43/150
# 12/12 [==============================] - 0s 7ms/step - loss: 9.7453 - mse: 9.7453 - val_loss: 11.8040 - val_mse: 11.8040
# Epoch 44/150
# 12/12 [==============================] - 0s 9ms/step - loss: 9.7936 - mse: 9.7936 - val_loss: 11.6678 - val_mse: 11.6678
# Epoch 45/150
# 12/12 [==============================] - 0s 9ms/step - loss: 9.8177 - mse: 9.8177 - val_loss: 11.6724 - val_mse: 11.6724
# Epoch 46/150
# 12/12 [==============================] - 0s 9ms/step - loss: 9.6333 - mse: 9.6333 - val_loss: 11.7124 - val_mse: 11.7124
# Epoch 47/150
# 12/12 [==============================] - 0s 8ms/step - loss: 9.6823 - mse: 9.6823 - val_loss: 11.7748 - val_mse: 11.7748
# Epoch 48/150
# 12/12 [==============================] - 0s 7ms/step - loss: 9.8162 - mse: 9.8162 - val_loss: 11.7955 - val_mse: 11.7955
# Epoch 49/150
# 12/12 [==============================] - 0s 8ms/step - loss: 9.5999 - mse: 9.5999 - val_loss: 11.7785 - val_mse: 11.7785
# Epoch 50/150
# 12/12 [==============================] - 0s 9ms/step - loss: 9.5790 - mse: 9.5790 - val_loss: 11.7617 - val_mse: 11.7617
# Epoch 51/150
# 12/12 [==============================] - 0s 9ms/step - loss: 9.6383 - mse: 9.6383 - val_loss: 11.8065 - val_mse: 11.8065
# Epoch 52/150
# 12/12 [==============================] - 0s 9ms/step - loss: 9.5886 - mse: 9.5886 - val_loss: 11.6250 - val_mse: 11.6250
# Epoch 53/150
# 12/12 [==============================] - 0s 9ms/step - loss: 9.4893 - mse: 9.4893 - val_loss: 11.5984 - val_mse: 11.5984
# Epoch 54/150
# 12/12 [==============================] - 0s 8ms/step - loss: 9.5272 - mse: 9.5272 - val_loss: 11.6236 - val_mse: 11.6236
# Epoch 55/150
# 12/12 [==============================] - 0s 7ms/step - loss: 9.5223 - mse: 9.5223 - val_loss: 11.6237 - val_mse: 11.6237
# Epoch 56/150
# 12/12 [==============================] - 0s 8ms/step - loss: 9.3979 - mse: 9.3979 - val_loss: 11.5881 - val_mse: 11.5881
# Epoch 57/150
# 12/12 [==============================] - 0s 8ms/step - loss: 9.4570 - mse: 9.4570 - val_loss: 11.5576 - val_mse: 11.5576
# Epoch 58/150
# 12/12 [==============================] - 0s 8ms/step - loss: 9.4142 - mse: 9.4142 - val_loss: 11.5381 - val_mse: 11.5381
# Epoch 59/150
# 12/12 [==============================] - 0s 8ms/step - loss: 9.5280 - mse: 9.5280 - val_loss: 12.3769 - val_mse: 12.3769
# Epoch 60/150
# 12/12 [==============================] - 0s 8ms/step - loss: 9.6976 - mse: 9.6976 - val_loss: 11.6134 - val_mse: 11.6134
# Epoch 61/150
# 12/12 [==============================] - 0s 9ms/step - loss: 9.4364 - mse: 9.4364 - val_loss: 12.2737 - val_mse: 12.2737
# Epoch 62/150
# 12/12 [==============================] - 0s 8ms/step - loss: 9.5844 - mse: 9.5844 - val_loss: 11.5870 - val_mse: 11.5870
# Epoch 63/150
# 12/12 [==============================] - 0s 7ms/step - loss: 9.6348 - mse: 9.6348 - val_loss: 11.8766 - val_mse: 11.8766
# Epoch 64/150
# 12/12 [==============================] - 0s 8ms/step - loss: 9.4134 - mse: 9.4134 - val_loss: 11.4736 - val_mse: 11.4736
# Epoch 65/150
# 12/12 [==============================] - 0s 8ms/step - loss: 9.1885 - mse: 9.1885 - val_loss: 11.6388 - val_mse: 11.6388
# Epoch 66/150
# 12/12 [==============================] - 0s 9ms/step - loss: 9.2650 - mse: 9.2650 - val_loss: 11.4329 - val_mse: 11.4329
# Epoch 67/150
# 12/12 [==============================] - 0s 8ms/step - loss: 9.2529 - mse: 9.2529 - val_loss: 11.4076 - val_mse: 11.4076
# Epoch 68/150
# 12/12 [==============================] - 0s 8ms/step - loss: 9.1562 - mse: 9.1562 - val_loss: 11.3686 - val_mse: 11.3686
# Epoch 69/150
# 12/12 [==============================] - 0s 7ms/step - loss: 9.1393 - mse: 9.1393 - val_loss: 11.3430 - val_mse: 11.3430
# Epoch 70/150
# 12/12 [==============================] - 0s 7ms/step - loss: 9.0716 - mse: 9.0716 - val_loss: 11.4357 - val_mse: 11.4357
# Epoch 71/150
# 12/12 [==============================] - 0s 7ms/step - loss: 9.1290 - mse: 9.1290 - val_loss: 11.3416 - val_mse: 11.3416
# Epoch 72/150
# 12/12 [==============================] - 0s 8ms/step - loss: 9.1183 - mse: 9.1183 - val_loss: 11.3766 - val_mse: 11.3766
# Epoch 73/150
# 12/12 [==============================] - 0s 7ms/step - loss: 9.2153 - mse: 9.2153 - val_loss: 11.2833 - val_mse: 11.2833
# Epoch 74/150
# 12/12 [==============================] - 0s 8ms/step - loss: 9.0355 - mse: 9.0355 - val_loss: 11.2458 - val_mse: 11.2458
# Epoch 75/150
# 12/12 [==============================] - 0s 8ms/step - loss: 9.0369 - mse: 9.0369 - val_loss: 11.3112 - val_mse: 11.3112
# Epoch 76/150
# 12/12 [==============================] - 0s 9ms/step - loss: 9.1609 - mse: 9.1609 - val_loss: 11.6855 - val_mse: 11.6855
# Epoch 77/150
# 12/12 [==============================] - 0s 7ms/step - loss: 9.2428 - mse: 9.2428 - val_loss: 11.3018 - val_mse: 11.3018
# Epoch 78/150
# 12/12 [==============================] - 0s 9ms/step - loss: 9.1250 - mse: 9.1250 - val_loss: 11.1883 - val_mse: 11.1883
# Epoch 79/150
# 12/12 [==============================] - 0s 8ms/step - loss: 8.8564 - mse: 8.8564 - val_loss: 11.5260 - val_mse: 11.5260
# Epoch 80/150
# 12/12 [==============================] - 0s 7ms/step - loss: 8.9838 - mse: 8.9838 - val_loss: 11.3927 - val_mse: 11.3927
# Epoch 81/150
# 12/12 [==============================] - 0s 7ms/step - loss: 9.0677 - mse: 9.0677 - val_loss: 11.1112 - val_mse: 11.1112
# Epoch 82/150
# 12/12 [==============================] - 0s 9ms/step - loss: 8.9512 - mse: 8.9512 - val_loss: 11.1192 - val_mse: 11.1192
# Epoch 83/150
# 12/12 [==============================] - 0s 8ms/step - loss: 9.1837 - mse: 9.1837 - val_loss: 13.4522 - val_mse: 13.4522
# Epoch 84/150
# 12/12 [==============================] - 0s 9ms/step - loss: 10.0385 - mse: 10.0385 - val_loss: 11.7351 - val_mse: 11.7351
# Epoch 85/150
# 12/12 [==============================] - 0s 7ms/step - loss: 9.0670 - mse: 9.0670 - val_loss: 11.1470 - val_mse: 11.1470
# Epoch 86/150
# 12/12 [==============================] - 0s 8ms/step - loss: 9.2474 - mse: 9.2474 - val_loss: 11.5213 - val_mse: 11.5213
# Epoch 87/150
# 12/12 [==============================] - 0s 8ms/step - loss: 8.8005 - mse: 8.8005 - val_loss: 11.0602 - val_mse: 11.0602
# Epoch 88/150
# 12/12 [==============================] - 0s 8ms/step - loss: 8.8446 - mse: 8.8446 - val_loss: 10.9899 - val_mse: 10.9899
# Epoch 89/150
# 12/12 [==============================] - 0s 8ms/step - loss: 8.8315 - mse: 8.8315 - val_loss: 10.9681 - val_mse: 10.9681
# Epoch 90/150
# 12/12 [==============================] - 0s 8ms/step - loss: 8.8234 - mse: 8.8234 - val_loss: 11.6200 - val_mse: 11.6200
# Epoch 91/150
# 12/12 [==============================] - 0s 9ms/step - loss: 8.9477 - mse: 8.9477 - val_loss: 10.9163 - val_mse: 10.9163
# Epoch 92/150
# 12/12 [==============================] - 0s 8ms/step - loss: 8.9906 - mse: 8.9906 - val_loss: 11.0333 - val_mse: 11.0333
# Epoch 93/150
# 12/12 [==============================] - 0s 7ms/step - loss: 8.9413 - mse: 8.9413 - val_loss: 11.2135 - val_mse: 11.2135
# Epoch 94/150
# 12/12 [==============================] - 0s 7ms/step - loss: 8.9852 - mse: 8.9852 - val_loss: 12.3573 - val_mse: 12.3573
# Epoch 95/150
# 12/12 [==============================] - 0s 9ms/step - loss: 9.0830 - mse: 9.0830 - val_loss: 10.9816 - val_mse: 10.9816
# Epoch 96/150
# 12/12 [==============================] - 0s 7ms/step - loss: 8.6912 - mse: 8.6912 - val_loss: 10.9713 - val_mse: 10.9713
# Epoch 97/150
# 12/12 [==============================] - 0s 9ms/step - loss: 8.6495 - mse: 8.6495 - val_loss: 11.0010 - val_mse: 11.0010
# Epoch 98/150
# 12/12 [==============================] - 0s 8ms/step - loss: 8.7096 - mse: 8.7096 - val_loss: 10.7399 - val_mse: 10.7399
# Epoch 99/150
# 12/12 [==============================] - 0s 9ms/step - loss: 8.5124 - mse: 8.5124 - val_loss: 10.7027 - val_mse: 10.7027
# Epoch 100/150
# 12/12 [==============================] - 0s 8ms/step - loss: 8.4478 - mse: 8.4478 - val_loss: 10.9565 - val_mse: 10.9565
# Epoch 101/150
# 12/12 [==============================] - 0s 9ms/step - loss: 8.8897 - mse: 8.8897 - val_loss: 10.6514 - val_mse: 10.6514
# Epoch 102/150
# 12/12 [==============================] - 0s 9ms/step - loss: 8.8386 - mse: 8.8386 - val_loss: 10.7616 - val_mse: 10.7616
# Epoch 103/150
# 12/12 [==============================] - 0s 8ms/step - loss: 8.4360 - mse: 8.4360 - val_loss: 10.6260 - val_mse: 10.6260
# Epoch 104/150
# 12/12 [==============================] - 0s 8ms/step - loss: 8.5846 - mse: 8.5846 - val_loss: 10.5924 - val_mse: 10.5924
# Epoch 105/150
# 12/12 [==============================] - 0s 8ms/step - loss: 8.6854 - mse: 8.6854 - val_loss: 10.7447 - val_mse: 10.7447
# Epoch 106/150
# 12/12 [==============================] - 0s 8ms/step - loss: 8.9095 - mse: 8.9095 - val_loss: 10.6442 - val_mse: 10.6442
# Epoch 107/150
# 12/12 [==============================] - 0s 9ms/step - loss: 8.3921 - mse: 8.3921 - val_loss: 10.5958 - val_mse: 10.5958
# Epoch 108/150
# 12/12 [==============================] - 0s 8ms/step - loss: 8.3081 - mse: 8.3081 - val_loss: 10.9713 - val_mse: 10.9713
# Epoch 109/150
# 12/12 [==============================] - 0s 8ms/step - loss: 8.4140 - mse: 8.4140 - val_loss: 10.5741 - val_mse: 10.5741
# Epoch 110/150
# 12/12 [==============================] - 0s 8ms/step - loss: 8.5372 - mse: 8.5372 - val_loss: 10.6049 - val_mse: 10.6049
# Epoch 111/150
# 12/12 [==============================] - 0s 8ms/step - loss: 8.4577 - mse: 8.4577 - val_loss: 10.7364 - val_mse: 10.7364
# Epoch 112/150
# 12/12 [==============================] - 0s 8ms/step - loss: 8.6558 - mse: 8.6558 - val_loss: 10.5672 - val_mse: 10.5672
# Epoch 113/150
# 12/12 [==============================] - 0s 8ms/step - loss: 8.3102 - mse: 8.3102 - val_loss: 10.4757 - val_mse: 10.4757
# Epoch 114/150
# 12/12 [==============================] - 0s 8ms/step - loss: 8.2346 - mse: 8.2346 - val_loss: 10.3699 - val_mse: 10.3699
# Epoch 115/150
# 12/12 [==============================] - 0s 7ms/step - loss: 8.1412 - mse: 8.1412 - val_loss: 10.4680 - val_mse: 10.4680
# Epoch 116/150
# 12/12 [==============================] - 0s 8ms/step - loss: 8.3170 - mse: 8.3170 - val_loss: 10.3924 - val_mse: 10.3924
# Epoch 117/150
# 12/12 [==============================] - 0s 7ms/step - loss: 8.2657 - mse: 8.2657 - val_loss: 10.2977 - val_mse: 10.2977
# Epoch 118/150
# 12/12 [==============================] - 0s 8ms/step - loss: 8.0840 - mse: 8.0840 - val_loss: 10.3369 - val_mse: 10.3369
# Epoch 119/150
# 12/12 [==============================] - 0s 8ms/step - loss: 8.2239 - mse: 8.2239 - val_loss: 10.3543 - val_mse: 10.3543
# Epoch 120/150
# 12/12 [==============================] - 0s 8ms/step - loss: 8.2203 - mse: 8.2203 - val_loss: 10.2283 - val_mse: 10.2283
# Epoch 121/150
# 12/12 [==============================] - 0s 8ms/step - loss: 8.0842 - mse: 8.0842 - val_loss: 10.7082 - val_mse: 10.7082
# Epoch 122/150
# 12/12 [==============================] - 0s 9ms/step - loss: 8.3449 - mse: 8.3449 - val_loss: 11.4066 - val_mse: 11.4066
# Epoch 123/150
# 12/12 [==============================] - 0s 7ms/step - loss: 8.6627 - mse: 8.6627 - val_loss: 12.7403 - val_mse: 12.7403
# Epoch 124/150
# 12/12 [==============================] - 0s 8ms/step - loss: 9.1672 - mse: 9.1672 - val_loss: 10.4080 - val_mse: 10.4080
# Epoch 125/150
# 12/12 [==============================] - 0s 8ms/step - loss: 8.3261 - mse: 8.3261 - val_loss: 10.6326 - val_mse: 10.6326
# Epoch 126/150
# 12/12 [==============================] - 0s 8ms/step - loss: 8.1619 - mse: 8.1619 - val_loss: 10.0817 - val_mse: 10.0817
# Epoch 127/150
# 12/12 [==============================] - 0s 8ms/step - loss: 7.9621 - mse: 7.9621 - val_loss: 10.2672 - val_mse: 10.2672
# Epoch 128/150
# 12/12 [==============================] - 0s 7ms/step - loss: 8.4496 - mse: 8.4496 - val_loss: 10.1421 - val_mse: 10.1421
# Epoch 129/150
# 12/12 [==============================] - 0s 9ms/step - loss: 8.0768 - mse: 8.0768 - val_loss: 10.2916 - val_mse: 10.2916
# Epoch 130/150
# 12/12 [==============================] - 0s 9ms/step - loss: 8.4645 - mse: 8.4645 - val_loss: 10.7025 - val_mse: 10.7025
# Epoch 131/150
# 12/12 [==============================] - 0s 7ms/step - loss: 8.1969 - mse: 8.1969 - val_loss: 10.1696 - val_mse: 10.1696
# Epoch 132/150
# 12/12 [==============================] - 0s 8ms/step - loss: 8.1318 - mse: 8.1318 - val_loss: 10.0779 - val_mse: 10.0779
# Epoch 133/150
# 12/12 [==============================] - 0s 7ms/step - loss: 7.9867 - mse: 7.9867 - val_loss: 11.3547 - val_mse: 11.3547
# Epoch 134/150
# 12/12 [==============================] - 0s 8ms/step - loss: 8.3503 - mse: 8.3503 - val_loss: 10.6221 - val_mse: 10.6221
# Epoch 135/150
# 12/12 [==============================] - 0s 8ms/step - loss: 8.1133 - mse: 8.1133 - val_loss: 10.0239 - val_mse: 10.0239
# Epoch 136/150
# 12/12 [==============================] - 0s 8ms/step - loss: 7.8137 - mse: 7.8137 - val_loss: 10.1889 - val_mse: 10.1889
# Epoch 137/150
# 12/12 [==============================] - 0s 8ms/step - loss: 8.0826 - mse: 8.0826 - val_loss: 10.5012 - val_mse: 10.5012
# Epoch 138/150
# 12/12 [==============================] - 0s 10ms/step - loss: 8.7851 - mse: 8.7851 - val_loss: 10.4140 - val_mse: 10.4140
# Epoch 139/150
# 12/12 [==============================] - 0s 8ms/step - loss: 8.3593 - mse: 8.3593 - val_loss: 10.0205 - val_mse: 10.0205
# Epoch 140/150
# 12/12 [==============================] - 0s 9ms/step - loss: 7.8439 - mse: 7.8439 - val_loss: 10.0080 - val_mse: 10.0080
# Epoch 141/150
# 12/12 [==============================] - 0s 8ms/step - loss: 7.7492 - mse: 7.7492 - val_loss: 10.0503 - val_mse: 10.0503
# Epoch 142/150
# 12/12 [==============================] - 0s 9ms/step - loss: 7.7856 - mse: 7.7856 - val_loss: 10.0822 - val_mse: 10.0822
# Epoch 143/150
# 12/12 [==============================] - 0s 9ms/step - loss: 8.0676 - mse: 8.0676 - val_loss: 9.9255 - val_mse: 9.9255
# Epoch 144/150
# 12/12 [==============================] - 0s 7ms/step - loss: 7.7788 - mse: 7.7788 - val_loss: 9.8134 - val_mse: 9.8134
# Epoch 145/150
# 12/12 [==============================] - 0s 8ms/step - loss: 7.7705 - mse: 7.7705 - val_loss: 10.2384 - val_mse: 10.2384
# Epoch 146/150
# 12/12 [==============================] - 0s 7ms/step - loss: 7.9160 - mse: 7.9160 - val_loss: 9.8857 - val_mse: 9.8857
# Epoch 147/150
# 12/12 [==============================] - 0s 7ms/step - loss: 8.1443 - mse: 8.1443 - val_loss: 10.1125 - val_mse: 10.1125
# Epoch 148/150
# 12/12 [==============================] - 0s 9ms/step - loss: 8.0663 - mse: 8.0663 - val_loss: 9.8524 - val_mse: 9.8524
# Epoch 149/150
# 12/12 [==============================] - 0s 8ms/step - loss: 7.7157 - mse: 7.7157 - val_loss: 9.7886 - val_mse: 9.7886
# Epoch 150/150
# 12/12 [==============================] - 0s 10ms/step - loss: 7.6092 - mse: 7.6092 - val_loss: 9.8227 - val_mse: 9.8227

# %%
plt.plot(history.history['mse'])
plt.plot(history.history['val_mse'])
plt.title('model mse')
plt.ylabel('mse')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
pred = model.predict(X_test).tolist()
pred = [p[0] for p in pred]
mean_squared_error(np.array(y_test), pred)
# Out:
# 9.822682861880883

# %%
r2_score(np.array(y_test), pred)
# Out:
# 0.9508526710626715

# %%
plt.scatter(y_test, pred)

# %% [markdown]
# - Neural network performed well, as epoch increased, MSE dropped.
# - However multiple regression outperformed neural network

# %% [markdown]
# # Regression without pretest variable

# %%
# %%R
# df.clean <- subset(df, select=-c(student_id, pretest))
#
# #approx 3/4 of whole dataset
# inds <- sample(nrow(df.clean), 1700)
# train <- df.clean[inds,]
# test <- df.clean[-inds,]
#
# fit1 <- lm(posttest ~ ., data=train)
# Anova(fit1)
# Out:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Note: model has aliased coefficients
#       sums of squares computed by model comparison
# Anova Table (Type II tests)
#
# Response: posttest
#                 Sum Sq   Df F value    Pr(>F)
# school                    0
# school_setting            0
# school_type               0
# classroom        40488   72  62.804 < 2.2e-16 ***
# teaching_method           0
# n_student                 0
# gender              96    1  10.765  0.001057 **
# lunch             1674    1 186.929 < 2.2e-16 ***
# Residuals        14335 1601
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# %%R
# train.clean.2 <- subset(train, select=-c(school, school_setting, school_type, teaching_method, n_student))
#
# fit2 <- lm(posttest ~ ., data=train.clean.2)
# Anova(fit2)
# Out:
# Anova Table (Type II tests)
#
# Response: posttest
#           Sum Sq   Df F value    Pr(>F)
# classroom 201435   96 234.347 < 2.2e-16 ***
# gender        96    1  10.765  0.001057 **
# lunch       1674    1 186.929 < 2.2e-16 ***
# Residuals  14335 1601
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# %%R
# X_test <- subset(test, select=-c(school, school_setting, school_type, n_student, teaching_method, posttest))
# Y_test <- subset(test, select=posttest)
# preds <- predict(fit2, X_test)

# %%
ytest = %R Y_test
pred = %R preds
ytest, pred = eval(ytest, pred)
# Out:
# MSE: 11.474669129174488
# R2Score: 0.9385225213795022

# %%
plt.scatter(ytest, pred)

# %% [markdown]
# Accuracy decreased slightly compared to the model with pretest variable.

# %% [markdown]
# ---
# # TREE
# - Same data that I used for neural nets

# %%
df_new = df.drop(columns=["student_id"])
df_new = pd.get_dummies(df_new)

from sklearn.model_selection import train_test_split

X = df_new.drop(columns=["posttest"], inplace=False)
y = df_new.posttest

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# ### Decision Tree

# %%
from sklearn import tree

clf = tree.DecisionTreeRegressor()
clf.fit(X_train, y_train)
pred = clf.predict(X_test)
print(f"MSE: {mean_squared_error(y_test, pred)}")
print(f"R2Score: {r2_score(y_test, pred)}")
# Out:
# MSE: 16.94974155618687
# R2Score: 0.915192770103838

# %%
importance = clf.feature_importances_
sorted_indices = np.argsort(importance)[::-1]
X_train.columns[sorted_indices]
def top_features(model):
    importance = model.feature_importances_
    sorted_indices = np.argsort(importance)[::-1][:10]
    cols = X_train.columns[sorted_indices]
    importance_dict={X_train.columns[i]:importance[i] for i in sorted_indices}
    plt.figure(figsize=(15,15))
    plt.barh(cols, importance[sorted_indices])
    plt.gca().invert_yaxis()

# %%
top_features(clf)

# %%
import graphviz 
dot_data = tree.export_graphviz(clf, out_file=None) 
graph = graphviz.Source(dot_data)
graph

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor()
rf.fit(X_train, y_train)
pred = rf.predict(X_test)
print(f"MSE: {mean_squared_error(y_test, pred)}")
print(f"R2Score: {r2_score(y_test, pred)}")
# Out:
# MSE: 11.087146534978139
# R2Score: 0.9445259869026666

# %%
top_features(rf)

# %% [markdown]
# ### LGBM

# %%
from lightgbm import LGBMRegressor

lgbm = LGBMRegressor()
evals=[(X_test, y_test)]
lgbm.fit(X_train, y_train, eval_set=evals, eval_metric="mse")
pred = lgbm.predict(X_test)
print(f"MSE: {mean_squared_error(y_test, pred)}")
print(f"R2Score: {r2_score(y_test, pred)}")
# Out:
# [1]	valid_0's l2: 164.567	valid_0's l2: 164.567
# [2]	valid_0's l2: 135.768	valid_0's l2: 135.768
# [3]	valid_0's l2: 112.292	valid_0's l2: 112.292
# [4]	valid_0's l2: 93.3963	valid_0's l2: 93.3963
# [5]	valid_0's l2: 77.7389	valid_0's l2: 77.7389
# [6]	valid_0's l2: 65.2135	valid_0's l2: 65.2135
# [7]	valid_0's l2: 54.9428	valid_0's l2: 54.9428
# [8]	valid_0's l2: 46.7366	valid_0's l2: 46.7366
# [9]	valid_0's l2: 39.9751	valid_0's l2: 39.9751
# [10]	valid_0's l2: 34.513	valid_0's l2: 34.513
# [11]	valid_0's l2: 30.0109	valid_0's l2: 30.0109
# [12]	valid_0's l2: 26.334	valid_0's l2: 26.334
# [13]	valid_0's l2: 23.3854	valid_0's l2: 23.3854
# [14]	valid_0's l2: 20.9653	valid_0's l2: 20.9653
# [15]	valid_0's l2: 19.0243	valid_0's l2: 19.0243
# [16]	valid_0's l2: 17.3803	valid_0's l2: 17.3803
# [17]	valid_0's l2: 16.0843	valid_0's l2: 16.0843
# [18]	valid_0's l2: 15.0054	valid_0's l2: 15.0054
# [19]	valid_0's l2: 14.0884	valid_0's l2: 14.0884
# [20]	valid_0's l2: 13.3617	valid_0's l2: 13.3617
# [21]	valid_0's l2: 12.761	valid_0's l2: 12.761
# [22]	valid_0's l2: 12.2829	valid_0's l2: 12.2829
# [23]	valid_0's l2: 11.8681	valid_0's l2: 11.8681
# [24]	valid_0's l2: 11.5303	valid_0's l2: 11.5303
# [25]	valid_0's l2: 11.2439	valid_0's l2: 11.2439
# [72]	valid_0's l2: 9.97408	valid_0's l2: 9.97408
# [73]	valid_0's l2: 9.96976	valid_0's l2: 9.96976
# [74]	valid_0's l2: 9.9581	valid_0's l2: 9.9581
# [75]	valid_0's l2: 9.96897	valid_0's l2: 9.96897
# [76]	valid_0's l2: 9.97468	valid_0's l2: 9.97468
# [77]	valid_0's l2: 9.98184	valid_0's l2: 9.98184
# [78]	valid_0's l2: 9.99184	valid_0's l2: 9.99184
# [79]	valid_0's l2: 9.99429	valid_0's l2: 9.99429
# [80]	valid_0's l2: 9.98807	valid_0's l2: 9.98807
# [81]	valid_0's l2: 9.98625	valid_0's l2: 9.98625
# [82]	valid_0's l2: 9.98219	valid_0's l2: 9.98219
# [83]	valid_0's l2: 9.974	valid_0's l2: 9.974
# [84]	valid_0's l2: 9.98608	valid_0's l2: 9.98608
# [85]	valid_0's l2: 9.97627	valid_0's l2: 9.97627
# [86]	valid_0's l2: 9.98824	valid_0's l2: 9.98824
# [87]	valid_0's l2: 9.99211	valid_0's l2: 9.99211
# [88]	valid_0's l2: 9.97668	valid_0's l2: 9.97668
# [89]	valid_0's l2: 9.97717	valid_0's l2: 9.97717
# [90]	valid_0's l2: 9.989	valid_0's l2: 9.989
# [91]	valid_0's l2: 9.98749	valid_0's l2: 9.98749
# [92]	valid_0's l2: 9.9916	valid_0's l2: 9.9916
# [93]	valid_0's l2: 10.0079	valid_0's l2: 10.0079
# [94]	valid_0's l2: 10.015	valid_0's l2: 10.015
# [95]	valid_0's l2: 10.0135	valid_0's l2: 10.0135
# [96]	valid_0's l2: 10.0066	valid_0's l2: 10.0066
# [97]	valid_0's l2: 10.0125	valid_0's l2: 10.0125
# [98]	valid_0's l2: 9.99586	valid_0's l2: 9.99586
# [99]	valid_0's l2: 9.99459	valid_0's l2: 9.99459
# [100]	valid_0's l2: 10.0111	valid_0's l2: 10.0111
# MSE: 10.011089931784921
# R2Score: 0.9499099852029227

# %%
from lightgbm import plot_importance
# %matplotlib inline

fig, ax = plt.subplots(figsize=(15,15))
plot_importance(lgbm, ax=ax)

# %% [markdown]
# ????? n_students and teaching method turned out to be very impactful.....?
# I can probably adjust the parameters of the models and use cross validation to improve the performance. Although the difference is marginal, performance is LGBM > RandomForest > DecisionTrees.

# %% [markdown]
# ---
# # Tree Models without pretest variable

# %%
df_new = df.drop(columns=["student_id", "pretest"])
df_new = pd.get_dummies(df_new)

from sklearn.model_selection import train_test_split

X = df_new.drop(columns=["posttest"], inplace=False)
y = df_new.posttest

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
clf = tree.DecisionTreeRegressor()
clf.fit(X_train, y_train)
pred = clf.predict(X_test)
print(f"MSE: {mean_squared_error(y_test, pred)}")
print(f"R2Score: {r2_score(y_test, pred)}")
# Out:
# MSE: 13.234022599647744
# R2Score: 0.9337841940929382

# %%
top_features(clf)

# %%
rf = RandomForestRegressor()
rf.fit(X_train, y_train)
rfpred = rf.predict(X_test)
print(f"MSE: {mean_squared_error(y_test, pred)}")
print(f"R2Score: {r2_score(y_test, pred)}")
top_features(rf)
# Out:
# MSE: 13.234022599647744
# R2Score: 0.9337841940929382

# %%
import plotly.express as px
px.line(X_test, rfpred)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="
# %%
lgbm = LGBMRegressor()
evals=[(X_test, y_test)]
lgbm.fit(X_train, y_train, eval_set=evals, eval_metric="mse")
pred = lgbm.predict(X_test)
print(f"MSE: {mean_squared_error(y_test, pred)}")
print(f"R2Score: {r2_score(y_test, pred)}")
# Out:
# [1]	valid_0's l2: 167.967	valid_0's l2: 167.967
# [2]	valid_0's l2: 141.956	valid_0's l2: 141.956
# [3]	valid_0's l2: 120.358	valid_0's l2: 120.358
# [4]	valid_0's l2: 102.967	valid_0's l2: 102.967
# [5]	valid_0's l2: 88.6734	valid_0's l2: 88.6734
# [6]	valid_0's l2: 77.1177	valid_0's l2: 77.1177
# [7]	valid_0's l2: 67.7473	valid_0's l2: 67.7473
# [8]	valid_0's l2: 60.207	valid_0's l2: 60.207
# [9]	valid_0's l2: 53.6887	valid_0's l2: 53.6887
# [10]	valid_0's l2: 48.338	valid_0's l2: 48.338
# [11]	valid_0's l2: 43.9265	valid_0's l2: 43.9265
# [12]	valid_0's l2: 40.3943	valid_0's l2: 40.3943
# [13]	valid_0's l2: 37.1456	valid_0's l2: 37.1456
# [14]	valid_0's l2: 34.487	valid_0's l2: 34.487
# [15]	valid_0's l2: 32.418	valid_0's l2: 32.418
# [16]	valid_0's l2: 30.6764	valid_0's l2: 30.6764
# [17]	valid_0's l2: 29.1837	valid_0's l2: 29.1837
# [18]	valid_0's l2: 27.7663	valid_0's l2: 27.7663
# [19]	valid_0's l2: 26.7717	valid_0's l2: 26.7717
# [20]	valid_0's l2: 25.7398	valid_0's l2: 25.7398
# [21]	valid_0's l2: 24.9545	valid_0's l2: 24.9545
# [22]	valid_0's l2: 24.3877	valid_0's l2: 24.3877
# [23]	valid_0's l2: 23.7717	valid_0's l2: 23.7717
# [24]	valid_0's l2: 23.2081	valid_0's l2: 23.2081
# [25]	valid_0's l2: 22.671	valid_0's l2: 22.671
# [26]	valid_0's l2: 22.3143	valid_0's l2: 22.3143
# [27]	valid_0's l2: 22.0125	valid_0's l2: 22.0125
# [28]	valid_0's l2: 21.6533	valid_0's l2: 21.6533
# [29]	valid_0's l2: 21.3138	valid_0's l2: 21.3138
# [30]	valid_0's l2: 21.0098	valid_0's l2: 21.0098
# [31]	valid_0's l2: 20.8082	valid_0's l2: 20.8082
# [32]	valid_0's l2: 20.6338	valid_0's l2: 20.6338
# [33]	valid_0's l2: 20.398	valid_0's l2: 20.398
# [34]	valid_0's l2: 20.2621	valid_0's l2: 20.2621
# [35]	valid_0's l2: 19.9114	valid_0's l2: 19.9114
# [36]	valid_0's l2: 19.6594	valid_0's l2: 19.6594
# [37]	valid_0's l2: 19.4249	valid_0's l2: 19.4249
# [38]	valid_0's l2: 19.209	valid_0's l2: 19.209
# [39]	valid_0's l2: 19.0517	valid_0's l2: 19.0517
# [86]	valid_0's l2: 16.4197	valid_0's l2: 16.4197
# [87]	valid_0's l2: 16.4093	valid_0's l2: 16.4093
# [88]	valid_0's l2: 16.3742	valid_0's l2: 16.3742
# [89]	valid_0's l2: 16.3693	valid_0's l2: 16.3693
# [90]	valid_0's l2: 16.3677	valid_0's l2: 16.3677
# [91]	valid_0's l2: 16.3757	valid_0's l2: 16.3757
# [92]	valid_0's l2: 16.3547	valid_0's l2: 16.3547
# [93]	valid_0's l2: 16.3478	valid_0's l2: 16.3478
# [94]	valid_0's l2: 16.3472	valid_0's l2: 16.3472
# [95]	valid_0's l2: 16.3271	valid_0's l2: 16.3271
# [96]	valid_0's l2: 16.3133	valid_0's l2: 16.3133
# [97]	valid_0's l2: 16.2903	valid_0's l2: 16.2903
# [98]	valid_0's l2: 16.2897	valid_0's l2: 16.2897
# [99]	valid_0's l2: 16.2695	valid_0's l2: 16.2695
# [100]	valid_0's l2: 16.2391	valid_0's l2: 16.2391
# MSE: 16.23914911625604
# R2Score: 0.9187481857552167

# %%
fig,ax = plt.subplots(figsize=(15,15))
plot_importance(lgbm, ax=ax)

# %% [markdown]
# # Cross validation w/ xgboost

# %%
from sklearn.model_selection import cross_validate
from xgboost import XGBRegressor
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
dtr = tree.DecisionTreeRegressor(max_depth=7)
rf = RandomForestRegressor()
xgb = XGBRegressor(n_estimators=1000, verbosity=0)

models = [lr, dtr, rf, xgb]

scoring = {'r2': 'r2',
          'mse':'neg_mean_squared_error'}

for model in models:
    scores = cross_validate(model, X, y, scoring=scoring, cv=5, return_train_score=True)
    print(model.__class__.__name__)
    print(f"Average train r2: {np.mean(scores['train_r2'])}")
    print(f"Average test r2: {np.mean(scores['test_r2'])}")
    print(f"Average train mse: {np.mean(scores['train_mse']) * -1}")
    print(f"Average test mse: {np.mean(scores['test_mse']) * -1}\n")
# Out:
# LinearRegression
# Average train r2: 0.9528623138915716
# Average test r2: -8.548824930149896e+22
# Average train mse: 9.011292722684868
# Average test mse: 1.2680295393929338e+25
#
# DecisionTreeRegressor
# Average train r2: 0.8898031741412533
# Average test r2: -0.0504597201907143
# Average train mse: 21.17715195639982
# Average test mse: 144.1755823851185
#
# RandomForestRegressor
# Average train r2: 0.9577944685442716
# Average test r2: 0.06041977777905161
# Average train mse: 8.075779950881355
# Average test mse: 131.62130534103787
#
# XGBRegressor
# Average train r2: 0.957539507672035
# Average test r2: 0.18359715426160586
# Average train mse: 8.125014696801657
# Average test mse: 109.57398430479354

# %% [markdown]
# I feel like the scores are very wrong...

# %% [markdown]
# # xgboost alone

# %%
xgb = XGBRegressor(n_estimators=1000, verbosity=0)
xgb.fit(X_train, y_train)
preds = xgb.predict(X_test)

print(f"MSE: {mean_squared_error(y_test, preds)}")
print(f"R2Score: {r2_score(y_test, preds)}")
# Out:
# MSE: 11.515308654575703
# R2Score: 0.9423836979958317

# %%
plt.scatter(y_test, preds)

# %%
from xgboost import plot_importance
plot_importance(xgb, max_num_features=10)

# %% [markdown]
# Gender is an important variable here
